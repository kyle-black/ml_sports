# %%
import pandas as pd

# %%
df=pd.read_csv('results2.csv')

# %%
df
# Out:
#      Unnamed: 0           home_team             away_team  home_is_winner  \
# 0          1013       New York Mets         Miami Marlins               1
# 1          1048  Los Angeles Angels  Washington Nationals               0
# 2           695   Cleveland Indians    Kansas City Royals               1
# 3           736     Minnesota Twins   Los Angeles Dodgers               0
# 4           723      Houston Astros     Chicago White Sox               1
# ..          ...                 ...                   ...             ...
# 257         572    New York Yankees     Baltimore Orioles               1
# 258         140       New York Mets     Baltimore Orioles               1
# 259         888      Tampa Bay Rays        Detroit Tigers               1
# 260         312    Seattle Mariners      Colorado Rockies               0
# 261         199      Boston Red Sox        Atlanta Braves               1
#
#      away_win_prob  home_win_prob
# 0         0.460387       0.539613
# ...

# %%
df[30:40]
# Out:
#     Unnamed: 0              home_team             away_team  home_is_winner  \
# 30         538         Detroit Tigers    Los Angeles Angels               0
# 31         427      Baltimore Orioles  Washington Nationals               1
# 32         682   Arizona Diamondbacks   Los Angeles Dodgers               0
# 33          63  Philadelphia Phillies  San Francisco Giants               0
# 34         390      Oakland Athletics     Cleveland Indians               0
# 35        1266          Texas Rangers      New York Yankees               0
# 36         208      Oakland Athletics    Los Angeles Angels               1
# 37         409         Houston Astros     Cleveland Indians               1
# 38          76        Cincinnati Reds  Arizona Diamondbacks               0
# 39         184   San Francisco Giants   Los Angeles Dodgers               0
#
#     away_win_prob  home_win_prob
# 30       0.465913       0.534087
# 31       0.349513       0.650487
# ...
