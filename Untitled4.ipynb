# %%
import pandas as pd

# %%
df = pd.read_csv('median_odds.csv')

# %%
df
# Out:
#       Unnamed: 0                           game_id             home_team  \
# 0              0  d18bceb2663d46029f10157b97e706b4  Washington Nationals
# 1              1  761f244afb0826308e05516d7ee62028   Los Angeles Dodgers
# 2              2  d18bceb2663d46029f10157b97e706b4  Washington Nationals
# 3              3  761f244afb0826308e05516d7ee62028   Los Angeles Dodgers
# 4              4  5362faebd839aba16645925fd2877f16         New York Mets
# ...          ...                               ...                   ...
# 3301        3301  c56ebf255ed5b3905fb4c2cd32fb1eca      Colorado Rockies
# 3302        3302  8571d48f75d0ade68b3897ca6319394d      San Diego Padres
# 3303        3303  793fd4271c4b703b7384c05e399f62f7     Oakland Athletics
# 3304        3304  75214037c234afa2564a0cf70be6856b   Los Angeles Dodgers
# 3305        3305  d8c3479002d2c2cc382b18fcad4eeff9        Houston Astros
#
#                   away_team         commence_time    id  \
# ...
