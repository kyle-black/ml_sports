# %%
import pandas as pd
from sklearn.metrics import r2_score, brier_score_loss

# %%
df =pd.read_csv('resultodds_new7.csv')

# %%
df
# Out:
#       Unnamed: 0  home_is_winner  home_score  away_score  home_diff  season
# 0             62               0           1           4         -3    2020  \
# 1             63               1           8           1          7    2020
# 2             82               0           1           4         -3    2020
# 3             83               1           8           1          7    2020
# 4            105               0           1           4         -3    2020
# ...          ...             ...         ...         ...        ...     ...
# 5267        8942               1           6           4          2    2023
# 5268        8943               1           5           4          1    2023
# 5269        8944               1           1           0          1    2023
# 5270        8945               1           6           3          3    2023
# 5271        8946               1           4           3          1    2023
#
# ...

# %%
filtered_data = df.loc[:, df.columns.str.endswith('_prob')|df.columns.str.endswith('diff')]

# %%
filtered_data
# Out:
#       home_diff  pinnacle_home_prob  pinnacle_away_prob  lowvig_home_prob
# 0            -3            0.440529            0.578059          0.444444  \
# 1             7            0.735450            0.288184          0.735450
# 2            -3            0.442478            0.578059          0.444444
# 3             7            0.735450            0.288184          0.735450
# 4            -3            0.446429            0.574468          0.444444
# ...         ...                 ...                 ...               ...
# 5267          2            0.586777            0.432900          0.591837
# 5268          1            0.425532            0.595142          0.423729
# 5269          1            0.586777            0.432900          0.581590
# 5270          3            0.586777            0.432900          0.581590
# 5271          1            0.585062            0.434783          0.588477
#
#       lowvig_away_prob  betonlineag_home_prob  betonlineag_away_prob
# ...
