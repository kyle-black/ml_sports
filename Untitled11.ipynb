# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score

# %%
df =pd.read_csv('game_predictions_and_odds13.csv')

# %%
df
# Out:
#                               game_id              home_team
# 0    748f9531bf9cfb2b29544eee0f8b3bcb          New York Mets  \
# 1    884cd68941ccf0d57073c5992abaaf14       Seattle Mariners
# 2    42b549cd9411fdbb4c7e35721b9635c1       Colorado Rockies
# 3    e940c5bd6dbbf0f4fcaa31bf9bbcc3ac   Washington Nationals
# 4    2507e4f72984f7aa5964bd982273831b   Arizona Diamondbacks
# ..                                ...                    ...
# 774  70ecb534a05c6d0c72d5cdefa79832f8       Colorado Rockies
# 775  121bbac7ecd46791e3efe0f425b3fa41  Philadelphia Phillies
# 776  334ab79b210d61afbaa8bdc1194eb177      Milwaukee Brewers
# 777  9b4cf4e321fcc6779ac66e183716f4a3      Oakland Athletics
# 778  b206fe61ba2692b4ec726ccfb16fa545      Toronto Blue Jays
#
#                 away_team  home_is_winner  home_odds  away_odds
# 0          Boston Red Sox               0     -145.0      135.0  \
# 1       Oakland Athletics               1     -161.0      148.0
# ...

# %%
r2 = r2_score(df['pinnacle_home'], df['home_is_winner'])
