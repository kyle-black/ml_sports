# %%
import pandas as pd

# %%
df =pd.read_csv('results.csv')

# %%
df
# Out:
#         id                   game_date  season              home_team  \
# 0       10  2022-03-17 00:00:00.000000    2022         Boston Red Sox
# 1       11  2022-03-17 00:00:00.000000    2022      Chicago White Sox
# 2       12  2022-03-17 00:00:00.000000    2022           Chicago Cubs
# 3       13  2022-03-17 00:00:00.000000    2022       Colorado Rockies
# 4       14  2022-03-18 00:00:00.000000    2022    St. Louis Cardinals
# ...    ...                         ...     ...                    ...
# 2734  2799  2022-10-29 00:00:00.000000    2022         Houston Astros
# 2735  2801  2022-11-01 00:00:00.000000    2022  Philadelphia Phillies
# 2736  2802  2022-11-02 00:00:00.000000    2022  Philadelphia Phillies
# 2737  2803  2022-11-03 00:00:00.000000    2022  Philadelphia Phillies
# 2738  2804  2022-11-05 00:00:00.000000    2022         Houston Astros
#
#                   away_team  home_score  away_score home_is_winner  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'game_date', 'season', 'home_team', 'away_team', 'home_score',
#        'away_score', 'home_is_winner', 'away_is_winner', 'game_type',
#        ...
#        'ERA+.1', 'FIP.1', 'WHIP.1', 'H9.1', 'HR9.1', 'BB9.1', 'SO9.1',
#        'SO/W.1', 'LOB.3', 'season.6'],
#       dtype='object', length=184)

# %%
for i in df.columns:
    print(i)
# Out:
# id
# game_date
# season
# home_team
# away_team
# home_score
# away_score
# home_is_winner
# away_is_winner
# game_type
# Tm
# #Bat
# BatAge
# R/G
# G
# PA
# AB
# R
# H
# 2B
# 3B
# HR
# RBI
# SB
# CS
# BB
# SO
# BA
# OBP
# SLG
# OPS
# OPS+
# TB
# GDP
# HBP
# SH
# SF
# IBB
# LOB
# season.1
# Tm.1
# #Bat.1
# BatAge.1
# R/G.1
# G.1
# PA.1
# AB.1
# R.1
# H.1
# 2B.1
# 3B.1
# HR.1
# RBI.1
# SB.1
# CS.1
# BB.1
# SO.1
# BA.1
# OBP.1
# SLG.1
# OPS.1
# OPS+.1
# TB.1
# GDP.1
# HBP.1
# SH.1
# SF.1
# IBB.1
# LOB.1
# season.2
# Tm.2
# #Fld
# RA/G
# DefEff
# G.2
# GS
# CG
# Inn
# Ch
# PO
# A
# E
# DP
# Fld%
# Rtot
# Rtot/yr
# Rdrs
# Rdrs/yr
# Rgood
# season.3
# Tm.3
# #Fld.1
# RA/G.1
# DefEff.1
# G.3
# GS.1
# CG.1
# Inn.1
# Ch.1
# PO.1
# A.1
# E.1
# DP.1
# Fld%.1
# Rtot.1
# Rtot/yr.1
# Rdrs.1
# Rdrs/yr.1
# Rgood.1
# season.4
# Tm.4
# #P
# PAge
# RA/G.2
# W
# L
# W-L%
# ERA
# G.4
# GS.2
# GF
# CG.2
# tSho
# cSho
# SV
# IP
# H.2
# R.2
# ER
# HR.2
# BB.2
# IBB.2
# SO.2
# HBP.2
# BK
# WP
# BF
# ERA+
# ...

# %%
df.to_csv('data/baseball/mlb/team_stats/2022/standings/standings_2022.csv')

# %%
df
