# %%
import pandas as pd

# %%
df = pd.read_csv('date_stats/winpct.csv')

# %%
df2 = pd.read_csv('date_stats/stats_R.csv')

# %%
df
# Out:
#        Unnamed: 0        Date         Team Current Last 3 Last 1   Home
# 0               0  2020-06-30      Houston   0.650  0.333  0.000  0.714  \
# 1               1  2020-06-30   LA Dodgers   0.647  0.333  0.000  0.714
# 2               2  2020-06-30   NY Yankees   0.632  0.333  0.000  0.698
# 3               3  2020-06-30    Minnesota   0.612  0.000  0.000  0.561
# 4               4  2020-06-30      Oakland   0.595  0.333  0.000  0.650
# ...           ...         ...          ...     ...    ...    ...    ...
# 17275        2935  2023-07-05    St. Louis   0.422  0.667  1.000  0.400
# 17276        2936  2023-07-05   Washington   0.410  0.667  1.000  0.325
# 17277        2937  2023-07-05     Colorado   0.384  0.333  0.000  0.455
# 17278        2938  2023-07-05  Kansas City   0.298  0.667  1.000  0.296
# 17279        2939  2023-07-05      Oakland   0.267  0.667  0.000  0.273
#
#         Away  Previous  Unnamed: 9
# 0      0.584     0.629         NaN
# ...

# %%
df['Current'][0]
# Out:
# '0.650'

# %%
df2
# Out:
#        Unnamed: 0        Date         Team Current Last 3 Last 1  Home  Away
# 0             0.0  2020-06-30   NY Yankees    5.77   3.67   4.00  5.42  6.13  \
# 1             1.0  2020-06-30    Minnesota    5.73   2.33   1.00  5.40  6.06
# 2             2.0  2020-06-30       Boston    5.56   3.33   5.00  5.46  5.66
# 3             3.0  2020-06-30      Houston    5.51   3.67   2.00  5.76  5.25
# 4             4.0  2020-06-30   LA Dodgers    5.44   4.67   3.00  5.38  5.49
# ...           ...         ...          ...     ...    ...    ...   ...   ...
# 22796      2815.0  2023-07-02        Miami    4.02   2.00   0.00  3.90  4.14
# 22797      2816.0  2023-07-02    Cleveland    4.00   3.33   6.00  3.54  4.42
# 22798      2817.0  2023-07-02      Detroit    3.82   5.67   4.00  4.05  3.60
# 22799      2818.0  2023-07-02  Kansas City    3.73   4.33   6.00  4.05  3.40
# 22800      2819.0  2023-07-02      Oakland    3.53   6.00   7.00  3.16  3.90
#
#        Previous  Unnamed: 9
# ...

# %%
df2['Current'][0]
# Out:
# '5.77'
