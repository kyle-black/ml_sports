# %%
import pandas as pd

# %%
df =pd.read_csv('bayesian/sigmoid_calibration/12features/5pct/win/test_set28.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'game_id', 'home_team', 'away_team', 'home_is_winner',
#        'home_odds', 'away_odds', 'home_implied_prob', 'away_implied_prob',
#        'model_home_win_prob', 'model_away_win_prob', 'homediff', 'awaydiff',
#        'bethome', 'betaway', 'game_won', 'game_lost', 'win', 'loss',
#        'bet_amount', 'bet_win', 'bankroll', 'net_bet_win', 'total_won_games',
#        'total_lost_games'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0                           game_id             home_team
# 0              0  83455c45e3ab097180f7206c179e903a      San Diego Padres  \
# 1              1  b94db4b6f78e3a9acfcfebd14661f5a4       Minnesota Twins
# 2              2  96e649dbb8561be8c68b59a209ad9819   St. Louis Cardinals
# 3              3  eb6c43f0c2abf60b3079c7fcff03a31b        Atlanta Braves
# 4              4  8bfb5fc93a3cbe7e6eb331ebda697618  Washington Nationals
# ...          ...                               ...                   ...
# 1069        1159  8162b45b4b22113506f9c34913addd5a        Tampa Bay Rays
# 1070        1161  cd72f24e0aec656c7c6f7ebb5f4e8489       Minnesota Twins
# 1071        1164  7be4f05d99754d74d1e8838215c04c2c  Arizona Diamondbacks
# 1072        1165  46d4b203727b2429a307c435dab1a96e    Kansas City Royals
# 1073        1166  6713926d9511e03c925dea8a08b3229a        Houston Astros
#
#                   away_team  home_is_winner  home_odds  away_odds
# ...

# %%
df =df[['home_team', 'away_team','home_is_winner','home_odds','away_odds','home_implied_prob', 'away_implied_prob','model_home_win_prob','model_away_win_prob','bethome','betaway','game_won', 'game_lost','win','loss','bet_amount','bankroll']]

# %%
df[:25]
# Out:
#                 home_team              away_team  home_is_winner  home_odds
# 0        San Diego Padres         Atlanta Braves               1      106.0  \
# 1         Minnesota Twins          Texas Rangers               0     -164.0
# 2     St. Louis Cardinals  Philadelphia Phillies               0     -112.0
# 3          Atlanta Braves        Cincinnati Reds               1     -187.0
# 4    Washington Nationals  Philadelphia Phillies               1      166.0
# 5        San Diego Padres       Colorado Rockies               0     -179.0
# 6        Seattle Mariners         Detroit Tigers               1     -240.0
# 7       Cleveland Indians      Milwaukee Brewers               0      130.0
# 8          Atlanta Braves  Philadelphia Phillies               1     -154.0
# 9    San Francisco Giants          Texas Rangers               1      117.0
# 10         Atlanta Braves     Pittsburgh Pirates               1     -238.0
# ...
